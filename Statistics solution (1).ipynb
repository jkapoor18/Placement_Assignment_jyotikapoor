# %% [markdown]
# # Q1 ANS

# %% [markdown]
# ***A correlation coefficient of 0.7 indicates a strong positive relationship between SAT scores and college GPA.
# a correlation coefficient of 0.7 suggests that as SAT scores increase, college GPA tends to increase as well. The positive sign indicates that the relationship is positive, meaning that higher SAT scores are associated with higher college GPAs.***

# %% [markdown]
# # Q2 ANS

# %% [markdown]
# ***Q-2. Consider a dataset containing the heights (in centimeters) of 1000 individuals. The
# mean height is 170 cm with a standard deviation of 10 cm. The dataset is approximately
# normally distributed, and its skewness is approximately zero. Based on this information,
# answer the following questions:***
#
# ***Q1 a. What percentage of individuals in the dataset have heights between 160 cm
# and 180 cm?***
#
# ***Ans:- To find the percentage of individuals with heights between 160 cm and 180 cm, we can use the z-score formula. The z-score represents the number of standard deviations an individual's height is from the mean.***
#
# The z-score formula is: z = (x - μ) / σ
#
# where:
# z = z-score ,x = individual's height ,μ = mean height ,σ = standard deviation
#
# For 160 cm: z1 = (160 - 170) / 10 = -1
#
# For 180 cm: z2 = (180 - 170) / 10 = 1
#
#  now use a standard normal distribution table or calculator to find the percentage of individuals between these z-scores Using the table the approximate percentage is 68%.
#
# ***Q2 b. If we randomly select 100 individuals from the dataset, what is the probability
# that their average height is greater than 175 cm?***
#
# Ans:-  The mean of the sample means will still be 170 cm because the distribution of the sample means is centered around the population mean. However, the standard deviation of the sample means will be given by the formula:
#
# σ(𝑥̅) = σ / √n
#
# where:
# σ(𝑥̅) = standard deviation of the sample means ,σ = standard deviation of the population ,n = sample size
#
# In this case, σ = 10 cm and n = 100. Therefore,
#
# σ(𝑥̅) = 10 / √100 = 10 / 10 = 1 cm
#
# We can use the z-score formula to calculate the probability that the average height is greater than 175 cm:
#
# z = (x - μ) / σ(𝑥̅)
# = (175 - 170) / 1
# = 5
#
# Using a standard normal distribution table or calculator, we find the probability of z > 5 to be very close to 0. Therefore, the probability that the average height of the randomly selected 100 individuals is greater than 175 cm is approximately 0.
#
# ***c. To find the z-score corresponding to a height of 185 cm, we can use the formula:***
#
# z = (x - μ) / σ
#
# where:
# z = z-score
# x = individual's height
# μ = mean height
# σ = standard deviation
#
# z = (185 - 170) / 10
# = 15 / 10
# = 1.5
#
# The z-score corresponding to a height of 185 cm is 1.5.
#
# ***d. If 5% of the dataset has heights below a certain value, we can find the threshold height by using a standard normal distribution table or calculator to find the z-score that corresponds to a cumulative probability of 0.05.***
#
# From the standard normal distribution table, the z-score corresponding to a cumulative probability of 0.05 (5%) is approximately -1.645.
#
# Using the z-score formula:
# -1.645 = (x - 170) / 10
#
# Solving for x:
#
# -1.645 * 10 = x - 170
#
# -16.45 = x - 170
#
# x ≈ 170 - 16.45
#
# x ≈ 153.55
#
# Therefore, the approximate height corresponding to the 5% threshold is 153.55 cm.
#
# ***e. The coefficient of variation (CV) is a measure of relative variability and is calculated as the ratio of the standard deviation to the mean. In this case, the CV can be calculated as:***
#
# CV = (σ / μ) * 100
#
# where:
#
# CV = coefficient of variation ,σ = standard deviation ,μ = mean
#
# CV = (10 / 170) * 100 ≈ 5.88
#
# Therefore, the coefficient of variation (CV) for the dataset is approximately 5.88%.
#
#
# ***F. Since the dataset is approximately normally distributed and its skewness is approximately zero, we can conclude that the skewness of the dataset is indeed close to zero.***

# %% [markdown]
# # Q. No. 3 ANS:-

# %% [markdown]
# Q-3. Consider the ‘Blood Pressure Before’ and ‘Blood Pressure After’ columns from the
# data and calculate the following
#
# https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_

# %%
import requests

def download_dataset_from_google_drive(url, output_file):
    file_id = url.split("/")[-2]
    base_url = "https://docs.google.com/uc?export=download"

    session = requests.Session()
    response = session.get(base_url, params={"id": file_id}, stream=True)
    token = get_confirm_token(response)

    if token:
        params = {"id": file_id, "confirm": token}
        response = session.get(base_url, params=params, stream=True)

    save_response_content(response, output_file)
    print(f"CSV file '{output_file}' created successfully.")

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith("download_warning"):
            return value

    return None

def save_response_content(response, output_file):
    CHUNK_SIZE = 32768

    with open(output_file, "wb") as file:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk:
                file.write(chunk)

# Example usage
url = "https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=sharing"
output_file = "output.csv"
download_dataset_from_google_drive(url, output_file)
# Out:
# CSV file 'output.csv' created successfully.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
df = pd.read_csv("output.csv")
df.head()
# Out:
#    Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)
# 0           1                            130                           120
# 1           2                            142                           135
# 2           3                            120                           118
# 3           4                            135                           127
# 4           5                            148                           140

# %%
#Q1. a. Measure the dispersion in both and interpret the results.
# Strip whitespace from column names
df.columns = df.columns.str.strip()

# Dispersion
disp_before = df['Blood Pressure Before (mmHg)'].var()
disp_after = df['Blood Pressure After (mmHg)'].var()

print(f"Dispersion Before: {disp_before}")
print(f"Dispersion After: {disp_after}")
# Out:
# Dispersion Before: 43.53727272727271
# Dispersion After: 47.4448484848485

# %%
#Q2.b. Calculate mean and 5% confidence interval and plot it in a graph
mean_before = df["Blood Pressure Before (mmHg)"].mean()
mean_after = df["Blood Pressure After (mmHg)"].mean()
confidence_interval_before = stats.t.interval(0.95, len(df)-1, loc=mean_before, scale=df["Blood Pressure Before (mmHg)"].sem())
confidence_interval_after = stats.t.interval(0.95, len(df)-1, loc=mean_after, scale=df["Blood Pressure After (mmHg)"].sem())
print("\nMean and 5% Confidence Interval:")
print("Before: Mean =", mean_before, "Confidence Interval =", confidence_interval_before)
print("After: Mean =", mean_after, "Confidence Interval =", confidence_interval_after)
# Out:
# Mean and 5% Confidence Interval:
# Before: Mean = 133.91 Confidence Interval = (132.60075849172767, 135.21924150827232)
# After: Mean = 128.36 Confidence Interval = (126.99326697818071, 129.7267330218193)

# %%
#Q3.c. Calculate the Mean absolute deviation and Standard deviation and interpret the results.
mean_before = df["Blood Pressure Before (mmHg)"].mad()
mean_after = df["Blood Pressure After (mmHg)"].mad()
sd_before = df["Blood Pressure Before (mmHg)"].std()
sd_after = df["Blood Pressure After (mmHg)"].std()
print("\nMean Absolute Deviation (Mean) and Standard Deviation (SD):")
print("Before: Mean =", mean_before, "SD =", sd_before)
print("After: Mean =", mean_after, "SD =", sd_after)
# Out:
# Mean Absolute Deviation (Mean) and Standard Deviation (SD):
# Before: Mean = 5.7118 SD = 6.598278012275075
# After: Mean = 5.9 SD = 6.8880221025232276

# %%
#Q4.d. Calculate the correlation coefficient and check the significance of it at 1% level of significance.
correlation_coefficient, p_value = stats.pearsonr(df["Blood Pressure Before (mmHg)"], df["Blood Pressure After (mmHg)"])
significance_level = 0.01

print("\nCorrelation Coefficient and Significance Test:")
print("Correlation Coefficient =", correlation_coefficient)
print("P-value =", p_value)

if p_value < significance_level:
    print("The correlation coefficient is significant at the 1% level.")
else:
    print("The correlation coefficient is not significant at the 1% level.")
# Out:
# Correlation Coefficient and Significance Test:
# Correlation Coefficient = 0.9779485966556017
# P-value = 1.8097381433072956e-68
# The correlation coefficient is significant at the 1% level.

# %% [markdown]
# # Q4 ANS

# %% [markdown]
# Q-4. A group of 20 friends decide to play a game in which they each write a number
# between 1 and 20 on a slip of paper and put it into a hat. They then draw one slip of paper
# at random. What is the probability that the number on the slip of paper is a perfect square
# (i.e., 1, 4, 9, or 16)?

# %%
#ans:-
# Number of favorable outcomes (perfect square numbers)
favorable_outcomes = 4

# Total number of possible outcomes
total_outcomes = 20

# Calculate the probability
probability = favorable_outcomes / total_outcomes

# Print the result
print(f"The probability of drawing a perfect square number is: {probability:.2f}")
# Out:
# The probability of drawing a perfect square number is: 0.20

# %% [markdown]
# # Q5  ANS

# %% [markdown]
# Q-5. A certain city has two taxi companies: Company A has 80% of the taxis and
# Company B has 20% of the taxis. Company A's taxis have a 95% success rate for picking
# up passengers on time, while Company B's taxis have a 90% success rate. If a randomly
# selected taxi is late, what is the probability that it belongs to Company A?

# %%
#Ans:-
# Probability of Company A having the taxis
P_A = 0.8

# Probability of Company B having the taxis
P_B = 0.2

# Probability of a taxi being late given it belongs to Company A
P_L_given_A = 0.05

# Probability of a taxi being late given it belongs to Company B
P_L_given_B = 0.1

# Calculate the probability of a taxi being late
P_L = (P_L_given_A * P_A) + (P_L_given_B * P_B)

# Calculate the probability that a randomly selected late taxi belongs to Company A
P_A_given_L = (P_L_given_A * P_A) / P_L

# Print the result
print(f"The probability that a randomly selected late taxi belongs to Company A is: {P_A_given_L:.4f}")
# Out:
# The probability that a randomly selected late taxi belongs to Company A is: 0.6667

# %% [markdown]
# # Q6 ANS

# %% [markdown]
# Q-6. A pharmaceutical company is developing a drug that is supposed to reduce blood
# pressure. They conduct a clinical trial with 100 patients and record their blood
# pressure before and after taking the drug. The company wants to know if the change
# in blood pressure follows a normal distribution.
#
# https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_

# %%
#Ans:-
from scipy import stats

# Blood pressure changes
blood_pressure_changes = [120-130, 135-142, 118-120, 127-135, 140-148, 118-122, 129-137, 124-130, 137-142, 125-128,
                          129-135, 132-140, 125-132, 136-145, 118-124, 122-128, 130-136, 139-143, 123-127, 132-139,
                          131-135, 126-131, 120-127, 123-130, 139-142, 122-128, 129-136, 136-140, 127-132, 140-145,
                          119-124, 121-128, 129-136, 137-143, 122-127, 135-139, 129-135, 124-131, 119-127, 124-130,
                          139-142, 123-128, 131-136, 135-140, 127-132, 141-145, 118-124, 121-128, 129-136]

# Perform Shapiro-Wilk test
statistic, p_value = stats.shapiro(blood_pressure_changes)

# Print the results
alpha = 0.05
print(f"Shapiro-Wilk test statistic: {statistic}")
print(f"p-value: {p_value}")

if p_value > alpha:
    print("The data follows a normal distribution.")
else:
    print("The data does not follow a normal distribution.")
# Out:
# Shapiro-Wilk test statistic: 0.9689664244651794
# p-value: 0.22020375728607178
# The data follows a normal distribution.

# %% [markdown]
# # Q7 ANS

# %% [markdown]
# Q-7. The equations of two lines of regression, obtained in a correlation analysis
# between variables X and Y are as follows:
#
# and . 2X + 3 − 8 = 0 2Y + X − 5 = 0 The variance of X = 4 Find the
# a. Variance of Y
# b. Coefficient of determination of C and Y
# c. Standard error of estimate of X on Y and of Y on X.

# %%
import numpy as np

# Given equations of regression lines
eq1 = lambda x: 2*x + 3 - 8
eq2 = lambda y: 2*y + 1 - 5

#1 Variance of X
var_x = 4

# a. Variance of Y
var_y = (var_x * (2**2)) / (2**2 + 1**2)
print("Variance of Y:", var_y)
# Out:
# Variance of Y: 3.2

# %%
#b. Coefficient of determination of C and Y
r_squared = var_y / var_x
print("Coefficient of determination (R-squared):", r_squared)
# Out:
# Coefficient of determination (R-squared): 0.8

# %%
#c. Standard error of estimate of X on Y and of Y on X.
se_x_on_y = np.sqrt(var_x * (1 - r_squared))
se_y_on_x = np.sqrt(var_y * (1 - r_squared))
print("Standard error of estimate of X on Y:", se_x_on_y)
print("Standard error of estimate of Y on X:", se_y_on_x)
# Out:
# Standard error of estimate of X on Y: 0.8944271909999157
# Standard error of estimate of Y on X: 0.7999999999999999

# %% [markdown]
# # Q8 Ans:

# %% [markdown]
# Q-8. The anxiety levels of 10 participants were measured before and after a new therapy.
# The scores are not normally distributed. Use the Wilcoxon signed-rank test to test whether
# the therapy had a significant effect on anxiety levels. The data is given below: Participant
# Before therapy After therapy Difference

# %%
from scipy.stats import wilcoxon

# Data
before_therapy = [10, 8, 12, 15, 6, 9, 11, 7, 14, 10]
after_therapy = [7, 6, 10, 12, 5, 8, 9, 6, 12, 8]

# Wilcoxon signed-rank test
statistic, p_value = wilcoxon(before_therapy, after_therapy)

# Print results
print("Wilcoxon signed-rank test:")
print("Statistic:", statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("The therapy had a significant effect on anxiety levels.")
else:
    print("The therapy did not have a significant effect on anxiety levels.")
# Out:
# Wilcoxon signed-rank test:
# Statistic: 0.0
# p-value: 0.001953125
# The therapy had a significant effect on anxiety levels.

# %% [markdown]
# # Q9 ANS:-

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# Create a DataFrame with student names and exam scores
data = pd.DataFrame({
    'Name': ['Karan', 'Deepa', 'Karthik', 'Chandan', 'Jeevan'],
    'Exam1': [85, 70, 90, 75, 95],
    'Exam2': [90, 80, 85, 70, 92],
    'Exam3': [92, 85, 88, 75, 96]
})

# Perform one-way ANOVA
statistic, p_value = stats.f_oneway(data['Exam1'], data['Exam2'], data['Exam3'])

# Print results
print("One-way ANOVA:")
print("F-statistic:", statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("The mean scores of the students are not the same.")
    highest_score_student = data['Name'][np.argmax(data[['Exam1', 'Exam2', 'Exam3']].values)]
    print("The student with the highest score is", highest_score_student)
else:
    print("The mean scores of the students are the same.")
# Out:
# One-way ANOVA:
# F-statistic: 0.3236947791164659
# p-value: 0.7295954253321559
# The mean scores of the students are the same.

# %% [markdown]
# # Q10 ANS

# %% [markdown]
# Q-10. A factory produces light bulbs, and the probability of a bulb being defective is 0.05.
# The factory produces a large batch of 500 light bulbs.
#
# a. What is the probability that exactly 20 bulbs are defective?
#
# b. What is the probability that at least 10 bulbs are defective?
#
# c. What is the probability that at max 15 bulbs are defective?
#
# d. On average, how many defective bulbs would you expect in a batch of 500?

# %%
import scipy.stats as stats

p = 0.05 # Probability of a bulb being defective
n = 500 # Total number of bulbs in the batch

# a. Probability of exactly 20 bulbs being defective
prob_20_defective = stats.binom.pmf(20, n, p)
print("Probability of exactly 20 bulbs being defective:", prob_20_defective)

# b. Probability of at least 10 bulbs being defective
prob_at_least_10_defective = 1 - stats.binom.cdf(9, n, p)
print("Probability of at least 10 bulbs being defective:", prob_at_least_10_defective)

# c. Probability of at most 15 bulbs being defective
prob_max_15_defective = stats.binom.cdf(15, n, p)
print("Probability of at most 15 bulbs being defective:", prob_max_15_defective)

# d. Expected number of defective bulbs in a batch of 500
expected_defective_bulbs = n * p
print("Expected number of defective bulbs in a batch of 500:", expected_defective_bulbs)
# Out:
# Probability of exactly 20 bulbs being defective: 0.051616192536641056
# Probability of at least 10 bulbs being defective: 0.9998316463654902
# Probability of at most 15 bulbs being defective: 0.01985837716300623
# Expected number of defective bulbs in a batch of 500: 25.0

# %% [markdown]
# # Q11 ANS

# %% [markdown]
# Q-11. Given the data of a feature contributing to different classes
#
# https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp
# =share_

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy.stats import f_oneway, bartlett
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
data= pd.read_csv("data.csv")
data.head()
# Out:
#    Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)
# 0           1                            130                           120
# 1           2                            142                           135
# 2           3                            120                           118
# 3           4                            135                           127
# 4           5                            148                           140

# %%
# a. Check whether the distribution of all the classes are the same or not
anova_result = f_oneway(data[' Blood Pressure Before (mmHg)'], data[' Blood Pressure After (mmHg)'])
if anova_result.pvalue < 0.05:
    print("The distribution of classes is not the same.")
else:
    print("The distribution of classes is the same.")
# Out:
# The distribution of classes is not the same.

# %%
# b. Check for the equality of variance
bartlett_result = bartlett(data[' Blood Pressure Before (mmHg)'], data[' Blood Pressure After (mmHg)'])
if bartlett_result.pvalue < 0.05:
    print("The variances are not equal.")
else:
    print("The variances are equal.")
# Out:
# The variances are equal.

# %%
#Q4d. Check the equality of mean for between all the classes.
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD post-hoc test
tukey_result = pairwise_tukeyhsd(df['Blood Pressure Before (mmHg)'], df['Patient ID'])
print(tukey_result)
# Out:
# C:\Users\jyoti\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\jyoti\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower upper reject
# -----------------------------------------------
#      1      2     12.0   nan   nan   nan  False
#      1      3    -10.0   nan   nan   nan  False
#      1      4      5.0   nan   nan   nan  False
#      1      5     18.0   nan   nan   nan  False
#      1      6     -8.0   nan   nan   nan  False
#      1      7      7.0   nan   nan   nan  False
#      1      8      0.0   nan   nan   nan  False
#      1      9     12.0   nan   nan   nan  False
#      1     10     -2.0   nan   nan   nan  False
# ...

# %% [markdown]
# # Q12 ANS

# %% [markdown]
# Q-12. A pharmaceutical company develops a new drug and wants to compare its
# effectiveness against a standard drug for treating a particular condition. They conduct a
# study with two groups: Group A receives the new drug, and Group B receives the standard
# drug. The company measures the improvement in a specific symptom for both groups after
# a 4-week treatment period.
#
# ***a.*** The company collects data from 30 patients in each group and calculates the
# mean improvement score and the standard deviation of improvement for each
# group. The mean improvement score for Group A is 2.5 with a standard
# deviation of 0.8, while the mean improvement score for Group B is 2.2 with a
# standard deviation of 0.6. Conduct a t-test to determine if there is a significant
# difference in the mean improvement scores between the two groups. Use a
# significance level of 0.05.
#
# ***b.*** Based on the t-test results, state whether the null hypothesis should be
# rejected or not. Provide a conclusion in the context of the study.

# %%
import scipy.stats as stats

mean_A = 2.5
std_deviation_A = 0.8
n_A = 30

mean_B = 2.2
std_deviation_B = 0.6
n_B = 30

# Calculate the t-value and p-value
t_value, p_value = stats.ttest_ind_from_stats(mean_A, std_deviation_A, n_A, mean_B, std_deviation_B, n_B)

# Compare the p-value with the significance level
significance_level = 0.05
if p_value < significance_level:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

# Provide a conclusion
if p_value < significance_level:
    print("There is a significant difference in the mean improvement scores between Group A and Group B.")
else:
    print("There is no significant difference in the mean improvement scores between Group A and Group B.")
# Out:
# Fail to reject the null hypothesis.
# There is no significant difference in the mean improvement scores between Group A and Group B.

# %% [markdown]
# ***B ANS***
#
# Based on the t-test results, we can compare the p-value to the significance level (0.05) to determine if the null hypothesis should be rejected or not. If the p-value is less than the significance level, we reject the null hypothesis and conclude that there is a significant difference in the mean improvement scores between the two groups. Otherwise, if the p-value is greater than or equal to the significance level, we fail to reject the null hypothesis, suggesting that there is no significant difference between the mean improvement scores of Group A and Group B.
#
# let's assume we obtained a p-value of 0.03 (less than 0.05). We would reject the null hypothesis and conclude that there is a significant difference in the mean improvement scores between the new drug (Group A) and the standard drug (Group B). This suggests that the new drug is more effective in improving the specific symptom compared to the standard drug.
